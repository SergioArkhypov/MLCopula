# %%
import pypandoc as pb
output1 = pb.convert_file('manuscript.md', 'html', outputfile='manuscript.html')
output2 = pb.convert_file('manuscript.md', 'docx', outputfile='manuscript.docx')

output3 = pb.convert_file('proposal.md', 'html', outputfile='proposal.html')
#output4 = pb.convert_file('proposal.md', 'docx', outputfile='proposal.docx')
output5 = pb.convert_file('proposal.md', 'docx', outputfile='proposal.docx', extra_args=[f"--reference-doc=template-wd.docx"])
#output6 = pb.convert_file('proposal.md', 'docx', outputfile='proposal2.docx', extra_args=[f"--reference-doc=template2.docx"])
#output5 = pb.convert_file('proposal.md', 'docx', outputfile='proposal3.docx', extra_args=[f"--reference-doc=template3.docx"])
#output6 = pb.convert_file('proposal.md', 'docx', outputfile='proposal4.docx', extra_args=[f"--reference-doc=template4.docx"])
# Out:
# [WARNING] Could not convert TeX math ES_{\alpha}(L) = \frac{1}{1-\alpha} \int_{\alpha}^{1} VaR_{p}(L) dp., rendering as TeX
